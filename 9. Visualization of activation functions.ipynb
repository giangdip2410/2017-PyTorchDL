# %% [markdown]
# Ref: https://www.youtube.com/watch?v=6YnzemVHvIU&index=10&list=PLXO45tsB95cJxT0mL0P3-G0rBcLSvVkKH

# %%
import torch
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt

# %% [markdown]
# # Create test data

# %%
x = torch.linspace(-5, 5, 200)

# %%
x = Variable(x)

# %%
x_np = x.data.numpy()

# %% [markdown]
# # Relu

# %%
y_relu = F.relu(x)

# %%
y_relu = y_relu.data.numpy()

# %%
plt.figure(figsize=(18,9)) # set the figure size to 18 x 9 inches
plt.plot(x_np, y_relu, c='red', label = 'relu')
plt.ylim((-1, 5))
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Sigmoid

# %%
y_sigmoid = F.sigmoid(x).data.numpy()

# %%
plt.figure(figsize=(18,9)) # set the figure size to 18 x 9 inches
plt.plot(x_np, y_sigmoid, c='red', label = 'sigmoid')
plt.ylim((-0.2, 1.2))
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # tanh

# %%
y_tanh = F.tanh(x).data.numpy()

# %%
plt.figure(figsize=(18,9)) # set the figure size to 18 x 9 inches
plt.plot(x_np, y_tanh, c='red', label = 'tanh')
plt.ylim((-1.2, 1.2))
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Softplus

# %%
y_softplus = F.softplus(x).data.numpy()

# %%
plt.figure(figsize=(18,9)) # set the figure size to 18 x 9 inches
plt.plot(x_np, y_softplus, c='red', label = 'softplus')
plt.ylim((-0.2, 6))
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Visualize 4 activation functions together

# %%
plt.figure(figsize=(18,9)) 

plt.subplot(2, 2, 1) # 2 rows * 2 columns
plt.plot(x_np, y_relu, c='red', label = 'relu')
plt.ylim((-1, 5))
plt.legend(loc='best')

plt.subplot(2, 2, 2)
plt.plot(x_np, y_sigmoid, c='red', label = 'sigmoid')
plt.ylim((-0.2, 1.2))
plt.legend(loc='best')

plt.subplot(2, 2, 3)
plt.plot(x_np, y_tanh, c='red', label = 'tanh')
plt.ylim((-1.2, 1.2))
plt.legend(loc='best')

plt.subplot(2, 2, 4)
plt.plot(x_np, y_softplus, c='red', label = 'softplus')
plt.ylim((-0.2, 6))
plt.legend(loc='best')

plt.show()
